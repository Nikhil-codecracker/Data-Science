# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Before.png')
glasses = cv2.imread('glasses.png')
mustache = cv2.imread('mustache.png')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
glasses = cv2.cvtColor(glasses,cv2.COLOR_BGR2GRAY)
mustache = cv2.cvtColor(mustache,cv2.COLOR_BGR2GRAY)
plt.imshow(mustache)
plt.show()
plt.imshow(glasses)
plt.show()
plt.imshow(img)
plt.show()
print(img.shape)
# Out:
# (485, 377, 3)

# %%
eyes_cascade = cv2.CascadeClassifier(".\third-party\frontalEyes35x16.xml")
eyes = eyes_cascade.detectMultiScale(img,1.3,5)
print(eyes.shape)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-35-6290d338c7f4> in <module>
#       1 eyes_cascade = cv2.CascadeClassifier(".\third-party\frontalEyes35x16.xml")
# ----> 2 eyes = eyes_cascade.detectMultiScale(img,1.3,5)
#       3 print(eyes.shape)
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'

# %%
print(img)
# Out:
# [[[219 202 180]
#   [220 203 181]
#   [219 202 180]
#   ...
#   [215 197 175]
#   [216 199 174]
#   [214 199 173]]
#
#  [[219 202 180]
#   [220 203 181]
#   [219 202 180]
#   ...
#   [215 198 176]
#   [216 199 175]
#   [214 199 173]]
#
#  [[219 202 180]
#   [220 203 181]
#   [219 202 180]
#   ...
#   [215 198 176]
#   [216 199 175]
#   [214 199 173]]
#
#  ...
#
#  [[  6   2   1]
#   [  5   1   0]
#   [  6   2   1]
#   ...
#   [ 27  21  21]
#   [ 26  20  20]
#   [ 17  10  10]]
#
#  [[  7   3   2]
#   [  6   2   1]
#   [  5   1   0]
#   ...
#   [ 22  16  16]
#   [ 21  15  15]
#   [ 22  16  16]]
#
#  [[  7   3   2]
#   [  5   1   0]
#   [  5   1   0]
#   ...
#   [ 19  13  13]
#   [ 21  15  15]
#   [ 22  15  15]]]

# %%
img = np.array(img)
img = np.resize(img,(img.shape[0]*img.shape[1],3))
# Out:
# [[219 202 180]
#  [220 203 181]
#  [219 202 180]
#  ...
#  [ 19  13  13]
#  [ 21  15  15]
#  [ 22  15  15]]

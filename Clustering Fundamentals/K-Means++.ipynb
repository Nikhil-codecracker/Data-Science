# %% [markdown]
# ### K-Means++
# - K-Means is quite sensitive to initilisation, if the init is not good, our algorithm is not able to make desired number of clusters.
# - To overcome this problem, we use the technique called K-Means++( described in paper https://arxiv.org/abs/1202.1585 (Robust Seed Selection for K-means type of Algorithm)) which chooses initial centers so that they are statically chose to final ones
# - The method is default choice for sklearn, so we will use it directly without going into much maths!

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(n_samples=500,n_features=2,centers=5,random_state=3)

# %%
from sklearn.cluster import KMeans

# %%
kmean = KMeans(n_clusters=5)

# %%
kmean.fit(X,y)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
centers = kmean.cluster_centers_

# %%
pred = kmean.labels_

# %%
plt.scatter(X[:,0],X[:,1],c=pred)
plt.scatter(centers[:,0],centers[:,1],marker="*",color='orange')
pt.title("Predictions")
plt.show()

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.title("Actual")
plt.show()

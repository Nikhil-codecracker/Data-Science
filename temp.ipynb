# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('C:/Users/nikhil/Desktop/classroom1.jpeg')
rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
print(img.shape)
# Out:
# (1170, 540, 3)

# %%
plt.imshow(rgb_image)
plt.show()
